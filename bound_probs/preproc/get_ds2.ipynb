# %%
import pandas as pd

import glob
import re
import os
import os.path as op

# %%
source_dir = op.join(os.environ['HOME'], 'Downloads', 'probDistortion_Sess05-Dec-2023')
reg = re.compile('.*/(?P<subject_id>[0-9]{2})/participant[0-9]+.[0-9]+_savedValues.csv')

fns = glob.glob(op.join(source_dir, '*', '*.csv'))

# [reg.match(fn).groupdict() for fn in fns]]


fns = [fn for fn in fns if reg.match(fn)]
subject_ids = [reg.match(fn).group(1) for fn in fns]
df = pd.concat([pd.read_csv(fn, index_col=[0,1,2]) for fn in fns], keys=subject_ids, names=['subject'])

df.to_csv(op.abspath('../data/ds2.csv'))

# %%
df
# Out:
#                                         outputRange  noiseType  \
# subject runNumber trialNumber probRange
# 03      1         1           00to100       00to100   lowNoise
#                   2           00to100       00to100   lowNoise
#                   3           00to100       00to100   lowNoise
#                   4           00to100       00to100   lowNoise
#                   5           00to100       00to100   lowNoise
# ...                                             ...        ...
# 22      6         21          00to050       00to100  highNoise
#                   22          00to050       00to100  highNoise
#                   23          00to050       00to100  highNoise
#                   24          00to050       00to100  highNoise
#                   25          00to050       00to100  highNoise
#
#                                          trialStartTime  presentedProb_1  \
# subject runNumber trialNumber probRange
# 03      1         1           00to100          0.156715               35
#                   2           00to100         11.674922                5
#                   3           00to100         23.072724               89
#                   4           00to100         34.563811               59
#                   5           00to100         46.056960               69
# ...                                                 ...              ...
# 22      6         21          00to050        230.043129             1175
#                   22          00to050        241.550938             3072
#                   23          00to050        253.047445              154
#                   24          00to050        264.552890             1165
#                   25          00to050        276.058965              849
#
#                                          presentedProb_2  certaintyEquivalent  \
# subject runNumber trialNumber probRange
# 03      1         1           00to100                100                 14.0
#                   2           00to100                100                  3.0
#                   3           00to100                100                 35.0
#                   4           00to100                100                 24.0
#                   5           00to100                100                 29.0
# ...                                                  ...                  ...
# 22      6         21          00to050               3016                 12.0
#                   22          00to050               9295                 10.0
#                   23          00to050               3195                  2.0
#                   24          00to050               2596                  9.0
#                   25          00to050               7755                  4.0
#
#                                          responseTime invalidResponses answer  \
# subject runNumber trialNumber probRange
# 03      1         1           00to100       11.000001              NaN    yes
#                   2           00to100       11.000001              NaN    yes
#                   3           00to100       11.000002              NaN    yes
#                   4           00to100       11.000001              NaN    yes
#                   5           00to100       11.000001              NaN    yes
# ...                                               ...              ...    ...
# 22      6         21          00to050       11.000001              NaN    yes
#                   22          00to050       11.000001              NaN    yes
#                   23          00to050       11.000001              NaN    yes
#                   24          00to050       11.000001              NaN    yes
#                   25          00to050       11.000001              NaN    yes
#
#                                         riskyValue lotteryExpectedValue  \
# subject runNumber trialNumber probRange
# 03      1         1           00to100           43                15.05
#                   2           00to100           43                 2.15
#                   3           00to100           43                38.27
#                   4           00to100           43                25.37
#                   5           00to100           43                29.67
# ...                                            ...                  ...
# 22      6         21          00to050           43            16.752321
#                   22          00to050           43            14.211512
#                   23          00to050           43             2.072613
#                   24          00to050           43            19.296995
#                   25          00to050           43             4.707544
#
#                                         probabilitySequence_1  \
# subject runNumber trialNumber probRange
# 03      1         1           00to100                      35
#                   2           00to100                       5
#                   3           00to100                      89
#                   4           00to100                      59
#                   5           00to100                      69
# ...                                                       ...
# 22      6         21          00to050                    1175
#                   22          00to050                    3072
#                   23          00to050                     154
#                   24          00to050                    1165
#                   25          00to050                     849
#
#                                         probabilitySequence_2 trialTimings  \
# subject runNumber trialNumber probRange
# 03      1         1           00to100                     100          0.0
#                   2           00to100                     100         11.5
#                   3           00to100                     100         23.0
#                   4           00to100                     100         34.5
#                   5           00to100                     100         46.0
# ...                                                       ...          ...
# 22      6         21          00to050                    3016        230.0
#                   22          00to050                    9295        241.5
#                   23          00to050                    3195        253.0
#                   24          00to050                    2596        264.5
#                   25          00to050                    7755        276.0
#
#                                         lotteryStartTimings lotteryEndTimings  \
# subject runNumber trialNumber probRange
# 03      1         1           00to100                   0.5              11.5
#                   2           00to100                  12.0              23.0
#                   3           00to100                  23.5              34.5
#                   4           00to100                  35.0              46.0
#                   5           00to100                  46.5              57.5
# ...                                                     ...               ...
# 22      6         21          00to050                 230.5             241.5
#                   22          00to050                 242.0             253.0
#                   23          00to050                 253.5             264.5
#                   24          00to050                 265.0             276.0
#                   25          00to050                 276.5             287.5
#
#                                         scaleStartTimings scaleEndTimings  \
# subject runNumber trialNumber probRange
# 03      1         1           00to100                 0.5            11.5
#                   2           00to100                12.0            23.0
#                   3           00to100                23.5            34.5
#                   4           00to100                35.0            46.0
#                   5           00to100                46.5            57.5
# ...                                                   ...             ...
# 22      6         21          00to050               230.5           241.5
#                   22          00to050               242.0           253.0
#                   23          00to050               253.5           264.5
#                   24          00to050               265.0           276.0
#                   25          00to050               276.5           287.5
#
#                                         responseStartTimings  \
# subject runNumber trialNumber probRange
# 03      1         1           00to100                    0.5
#                   2           00to100                   12.0
#                   3           00to100                   23.5
#                   4           00to100                   35.0
#                   5           00to100                   46.5
# ...                                                      ...
# 22      6         21          00to050                  230.5
#                   22          00to050                  242.0
#                   23          00to050                  253.5
#                   24          00to050                  265.0
#                   25          00to050                  276.5
#
#                                         responseEndTimings
# subject runNumber trialNumber probRange
# 03      1         1           00to100                 11.5
#                   2           00to100                 23.0
#                   3           00to100                 34.5
#                   4           00to100                 46.0
#                   5           00to100                 57.5
# ...                                                    ...
# 22      6         21          00to050                241.5
#                   22          00to050                253.0
#                   23          00to050                264.5
#                   24          00to050                276.0
#                   25          00to050                287.5
#
# [4800 rows x 20 columns]
